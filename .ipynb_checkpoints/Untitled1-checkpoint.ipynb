# %%
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np

# %%
data = np.genfromtxt("viscosity_results.csv", delimiter=",", names=["x", "y"])
plt.plot(data['x'], data['y'])
plt.xlabel('Temperature (K)', fontsize=12)
plt.ylabel('Viscosity ()', fontsize=12)
# Out:
# Text(0, 0.5, 'Viscosity ()')
